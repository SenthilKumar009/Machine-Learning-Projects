# %%
# This course will cover the complete concepts of the pandas required for implmenting Machine Learning algorithms using Python.

# %% [markdown]
# # 1. Introduction

# %%
import pandas as pd

# %%
# Read the dataset (cvs file) from the folder
df = pd.read_csv('data/survey_results_public_2020.csv')

# %%
# To display the top of the dataset records
# by default head() method will return 5 records.
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
# to display the records based on the user need, user should specify the record needs to be display
df.head(3)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  ...  \
# 0  Monthly        NaN            NaN             Germany   European Euro  ...
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling  ...
# 2      NaN        NaN            NaN  Russian Federation             NaN  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# ...

# %%
# To display the bottom of the records
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64456            NaN  United States          NaN  ...        NaN          NaN
# 64457            NaN        Morocco          NaN  ...        NaN          NaN
# 64458            NaN       Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN         Poland          NaN  ...        NaN          NaN
# 64460            NaN          Spain          NaN  ...        NaN          NaN
#
# ...

# %%
# To view the total row and column details of the dataset
df.shape

# (row, column)
# Out:
# (64461, 61)

# %%
# To display the total records count, column count, non-null count and datatype details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
# To view all the row and column details in the Notebook'
pd.set_option('display.max_columns', 63)
pd.set_option('display.max_rows', 63)
# Here we are specifying the total columns should display on the jupyter notebook

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema_2020.csv')
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
# To display only specific set of columns/ create a new dataframe from the existing dataframe
df[['Country', 'CurrencySymbol']]
# Out:
#                   Country CurrencySymbol
# 0                 Germany            EUR
# 1          United Kingdom            GBP
# 2      Russian Federation            NaN
# 3                 Albania            ALL
# 4           United States            NaN
# ...                   ...            ...
# 64456       United States            NaN
# 64457             Morocco            NaN
# 64458            Viet Nam            NaN
# 64459              Poland            NaN
# 64460               Spain            NaN
#
# [64461 rows x 2 columns]

# %%
# To display all the column names
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# ## # To display the specific row details we can use the loc and iloc methods

# %%
# To display a record using integer location we should use "iloc" method

# 1. iloc() - > access the records based on the integer location
df.iloc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
# To get multiple records from the dataframe
df.iloc[0:3]
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
# 2            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
# ...

# %%
# To select the row and column from the dataset using iloc method
df.iloc[[0,3], [1,2]]
# Out:
#                        MainBranch Hobbyist
# 0  I am a developer by profession      Yes
# 3  I am a developer by profession      Yes

# %%
df.iloc[0:3, 1:3]
# Out:
#                        MainBranch Hobbyist
# 0  I am a developer by profession      Yes
# 1  I am a developer by profession       No
# 2     I code primarily as a hobby      Yes

# %%
# 2. loc -> to select the records based on the index
df.loc[[1,2]]
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
#
#   CurrencySymbol DatabaseDesireNextYear DatabaseWorkedWith  \
# 1            GBP                    NaN                NaN
# 2            NaN                    NaN                NaN
#
#                                    DevType  \
# 1  Developer, full-stack;Developer, mobile
# 2                                      NaN
#
#                                         EdLevel          Employment Ethnicity  \
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time       NaN
# ...

# %%
# To select the specific columns for the selected rows, we need to pass the labels(column names) in the loc method
df.loc[[1,2],'Country']
# Out:
# 1        United Kingdom
# 2    Russian Federation
# Name: Country, dtype: object

# %%
df.loc[[1,2],['Country', 'CurrencySymbol']]
# Out:
#               Country CurrencySymbol
# 1      United Kingdom            GBP
# 2  Russian Federation            NaN

# %%
# To display the specific column from the specific rows from the dataset.
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
# Slice the dataset using loc method
df.loc[0:2, 'Hobbyist':'Employment']
# When slicing the dataset we should not use as a list ([])
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...

# %%
# To set the index 
schema_df.set_index('Column')
schema_df.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
# Should use inplace parameter as True to make permenent changes
schema_df.set_index('Column', inplace=True)
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %% [markdown]
# if the index was updated with the column values present in the dataset such as 'email'/ 'empid', etc loc() method no longer will take the index value of 0,1,2... it will take only the email/empid etc

# %%
# to rest the index
schema_df.reset_index(inplace=True)
schema_df.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
# How to set the column while reading the dataset
schema_df = pd.read_csv('data/survey_results_schema_2020.csv', index_col='Column')
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['UndergradMajor']
# Out:
# QuestionText    What was your primary field of study?
# Name: UndergradMajor, dtype: object

# %%
# Sort the dataset based on the index
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
# Sort the index in reverse order
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# ...

# %% [markdown]
# ### Filtering - Using Conditional to Filter Cows and Columns

# %%
df[df['Country'] == 'India']

# df['Country'] == 'India' -> This will return the true/ false values which indicates, 
# how many columns india (True) and not contains india (False)

# df[df['Country'] == 'India'] -> Will return the records which contains only True value
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
# Store the filter condition in a variable and apply on the dataset
filt = (df['Country'] == 'India')
df[filt]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
# Using loc method
df.loc[filt].head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc CurrencySymbol      DatabaseDesireNextYear  \
# 6    United States dollar            USD                         NaN
# ...

# %%
df.loc[filt, ['MainBranch', 'CurrencySymbol']]
# Out:
#                                    MainBranch CurrencySymbol
# 6              I am a developer by profession            USD
# 21             I am a developer by profession            INR
# 57             I am a developer by profession            INR
# 62     I am a student who is learning to code            NaN
# 147            I am a developer by profession            INR
# ...                                       ...            ...
# 64391                                     NaN            NaN
# 64398                                     NaN            NaN
# 64439                                     NaN            NaN
# 64442                                     NaN            NaN
# 64452                                     NaN            NaN
#
# [8403 rows x 2 columns]

# %% [markdown]
# **Filter using & and | condition**

# %%
filt = (df['Country'] == 'India') & (df['CurrencySymbol'] == 'INR')
df[filt].head()
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 21           22  I am a developer by profession      Yes   NaN         18
# 57           58  I am a developer by profession      Yes   NaN         22
# 147         149  I am a developer by profession      Yes  36.0         31
# 175         177  I am a developer by profession      Yes   NaN         18
# 225         227  I am a developer by profession      Yes  24.0         19
#
#     CompFreq   CompTotal  ConvertedComp Country  CurrencyDesc CurrencySymbol  \
# 21   Monthly         NaN            NaN   India  Indian rupee            INR
# 57       NaN         NaN            NaN   India  Indian rupee            INR
# 147   Yearly  21000000.0       293196.0   India  Indian rupee            INR
# 175  Monthly         NaN            NaN   India  Indian rupee            INR
# 225   Yearly    840000.0        11728.0   India  Indian rupee            INR
#
#          DatabaseDesireNextYear    DatabaseWorkedWith  \
# ...

# %%
# To display the records other than the filtered values
filt = (df['Country'] == 'India') & (df['CurrencySymbol'] == 'INR')
df[~filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
# Retuen the employees who are all getting the max salary
#df['ConvertedComp'].max()
filt = df['ConvertedComp'] == df['ConvertedComp'].max()
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 121           123                     I am a developer by profession      Yes
# 123           125  I am not primarily a developer, but I write co...      Yes
# 191           193                     I am a developer by profession      Yes
# 663           665                     I am a developer by profession      Yes
# 697           699  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 61417       62660                     I am a developer by profession      Yes
# 63459       64874                     I am a developer by profession      Yes
# 63890       65341                     I am a developer by profession      Yes
# 64035       65502                     I am a developer by profession      Yes
# 64057       65527                     I am a developer by profession      Yes
#
# ...

# %%
###------------------------------------------------------------------------------------------------------------------------###

# %%
import numpy as np

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20210101', periods=6)
dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns = list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840

# %%
df2 = pd.DataFrame({ 'A': 1,
                     'B': pd.Timestamp('20210101'),
                     'C': pd.Series(1, index=list(range(4)), dtype='float'),
                     'D': np.array([3] * 4,dtype='int32'),
                     'E': pd.Categorical(["test","train","test","train"]),
                     'F': 'foo' })
df2
# Out:
#    A          B    C  D      E    F
# 0  1 2021-01-01  1.0  3   test  foo
# 1  1 2021-01-01  1.0  3  train  foo
# 2  1 2021-01-01  1.0  3   test  foo
# 3  1 2021-01-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.01315887, -1.142554  , -0.78145587, -1.54903951],
#        [ 1.50978568, -0.03768749, -0.3672088 ,  2.00881561],
#        [ 0.45454313, -0.87684363, -1.11409714, -0.50893647],
#        [ 0.53060382, -0.70215755,  2.47925731,  2.46136489],
#        [ 0.10121793,  0.34539813,  1.21266866, -0.87789907],
#        [-0.80684532, -0.98266113,  0.08674955, -0.99883994]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.129358 -0.566084  0.252652  0.089244
# std    0.933267  0.588378  1.358568  1.701341
# min   -1.013159 -1.142554 -1.114097 -1.549040
# 25%   -0.579830 -0.956207 -0.677894 -0.968605
# 50%    0.277881 -0.789501 -0.140230 -0.693418
# 75%    0.511589 -0.203805  0.931189  1.379378
# max    1.509786  0.345398  2.479257  2.461365

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840

# %%
df.T
# Out:
#    2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  2021-01-06
# A   -1.013159    1.509786    0.454543    0.530604    0.101218   -0.806845
# B   -1.142554   -0.037687   -0.876844   -0.702158    0.345398   -0.982661
# C   -0.781456   -0.367209   -1.114097    2.479257    1.212669    0.086750
# D   -1.549040    2.008816   -0.508936    2.461365   -0.877899   -0.998840

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2021-01-01 -1.549040 -0.781456 -1.142554 -1.013159
# 2021-01-02  2.008816 -0.367209 -0.037687  1.509786
# 2021-01-03 -0.508936 -1.114097 -0.876844  0.454543
# 2021-01-04  2.461365  2.479257 -0.702158  0.530604
# 2021-01-05 -0.877899  1.212669  0.345398  0.101218
# 2021-01-06 -0.998840  0.086750 -0.982661 -0.806845

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899

# %%
### Selection Types in Pandas ###

# %%
# Retrive the data by provinding label (column) value
df['A']
# Out:
# 2021-01-01   -1.013159
# 2021-01-02    1.509786
# 2021-01-03    0.454543
# 2021-01-04    0.530604
# 2021-01-05    0.101218
# 2021-01-06   -0.806845
# Freq: D, Name: A, dtype: float64

# %%
# Extract the data by providing start and end index value
df[0:3]
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936

# %%
df['20210101': '20210103']
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936

# %%
# using loc (label) method #
df.loc[dates[0]]
# Out:
# A   -1.013159
# B   -1.142554
# C   -0.781456
# D   -1.549040
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2021-01-01 -1.013159 -1.142554
# 2021-01-02  1.509786 -0.037687
# 2021-01-03  0.454543 -0.876844
# 2021-01-04  0.530604 -0.702158
# 2021-01-05  0.101218  0.345398
# 2021-01-06 -0.806845 -0.982661

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840

# %%
# select data using iloc (position) method
df.iloc[0:3]
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936

# %%
df.iloc[3]
# Out:
# A    0.530604
# B   -0.702158
# C    2.479257
# D    2.461365
# Name: 2021-01-04 00:00:00, dtype: float64

# %%
df.iloc[2:5, 1:4]
# Out:
#                    B         C         D
# 2021-01-03 -0.876844 -1.114097 -0.508936
# 2021-01-04 -0.702158  2.479257  2.461365
# 2021-01-05  0.345398  1.212669 -0.877899

# %%
df.mean()
# Out:
# A    0.129358
# B   -0.566084
# C    0.252652
# D    0.089244
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2021-01-01   -1.121552
# 2021-01-02    0.778426
# 2021-01-03   -0.511334
# 2021-01-04    1.192267
# 2021-01-05    0.195346
# 2021-01-06   -0.675399
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan, 6,8], index=dates).shift(2)
s
# Out:
# 2021-01-01    NaN
# 2021-01-02    NaN
# 2021-01-03    1.0
# 2021-01-04    3.0
# 2021-01-05    5.0
# 2021-01-06    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  1.509786 -0.037687 -0.367209  2.008816
# 2021-01-03  0.454543 -0.876844 -1.114097 -0.508936
# 2021-01-04  0.530604 -0.702158  2.479257  2.461365
# 2021-01-05  0.101218  0.345398  1.212669 -0.877899
# 2021-01-06 -0.806845 -0.982661  0.086750 -0.998840

# %%
df.sub(s, axis ='index')
# Out:
#                    A         B         C         D
# 2021-01-01       NaN       NaN       NaN       NaN
# 2021-01-02       NaN       NaN       NaN       NaN
# 2021-01-03 -0.545457 -1.876844 -2.114097 -1.508936
# 2021-01-04 -2.469396 -3.702158 -0.520743 -0.538635
# 2021-01-05 -4.898782 -4.654602 -3.787331 -5.877899
# 2021-01-06       NaN       NaN       NaN       NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2021-01-01 -1.013159 -1.142554 -0.781456 -1.549040
# 2021-01-02  0.496627 -1.180241 -1.148665  0.459776
# 2021-01-03  0.951170 -2.057085 -2.262762 -0.049160
# 2021-01-04  1.481774 -2.759243  0.216496  2.412205
# 2021-01-05  1.582992 -2.413845  1.429164  1.534305
# 2021-01-06  0.776146 -3.396506  1.515914  0.535466

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    4
# 1    1
# 2    5
# 3    4
# 4    2
# 5    0
# 6    4
# 7    1
# 8    1
# 9    4
# dtype: int32

# %%
s.value_counts()
# Out:
# 4    4
# 1    3
# 5    1
# 2    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.183183 -1.215959  0.887434 -0.775705
# 1 -0.383852 -0.089321 -0.717206  0.467919
# 2 -1.024624 -0.508574 -1.394413  1.443712
# 3 -0.824754 -0.930757  1.030791 -0.397240
# 4 -0.002697  0.409014 -0.027411  1.564220
# 5  0.003020  1.244793 -0.604386  1.451621
# 6 -0.259311 -0.003389  0.416134 -0.028976
# 7 -1.418356  0.532498 -0.327610 -0.840819
# 8 -0.811463 -0.475978 -2.196979 -1.198441
# 9 -0.054981  0.283897 -0.780853 -0.709626

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.183183 -1.215959  0.887434 -0.775705
# 1 -0.383852 -0.089321 -0.717206  0.467919
# 2 -1.024624 -0.508574 -1.394413  1.443712
# 3 -0.824754 -0.930757  1.030791 -0.397240
# 4 -0.002697  0.409014 -0.027411  1.564220
# 5  0.003020  1.244793 -0.604386  1.451621
# 6 -0.259311 -0.003389  0.416134 -0.028976
# 7 -1.418356  0.532498 -0.327610 -0.840819
# 8 -0.811463 -0.475978 -2.196979 -1.198441
# 9 -0.054981  0.283897 -0.780853 -0.709626

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5
